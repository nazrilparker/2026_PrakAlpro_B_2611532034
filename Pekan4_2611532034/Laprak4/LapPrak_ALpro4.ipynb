# %% [markdown]
# <div align="center">
#
# LAPORAN PRAKTIKUM
#
# STRUKTUR DATA
#
# “STRUKTUR PERCABANGAN PADA PYTHON”
#
# Disusun Oleh :
#
# Muhammad Nazril Fandhi
#
# 2611532034
#
# Dosen Pengampu:
#
# Wahyudi.DR.. S.T.M.T
#
# Asisten Praktikum:
#
# Sherly Sukmadira
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# FAKULTAS TEKNOLOGI INFORMASI
#
# DEPARTEMEN INFORMATIKA
#
# UNIVERSITAS ANDALAS
#
# 2026
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum "Struktur Percabangan pada Python" yang telah dilaksanakan sebagai pertemuan ke-4 untuk mata kuliah Algoritma Pemrograman. Praktikum ini berfokus pada pembahasan struktur percabangan pada bahasa pemrograman Python, yang digunakan untuk mengatur jalannya program berdasarkan kondisi tertentu. Materi yang dibahas meliputi penggunaan if, if-else, if-elif-else, multi-if, operator logika, serta match-case.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep kerja struktur percabangan pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026
#
# Muhammad Nazril Fandhi

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Algoritma dan pemrograman merupakan salah satu dasar penting dalam bidang ilmu komputer. Dalam pembuatan sebuah program, diperlukan suatu logika agar program dapat menjalankan perintah sesuai dengan kondisi yang dihadapi. Salah satu konsep dasar yang digunakan untuk mengatur alur program tersebut adalah struktur percabangan.
#
# Python menyediakan beberapa bentuk struktur percabangan, seperti if, if-else, dan if-elif-else. Struktur tersebut digunakan untuk mengatur alur program berdasarkan kondisi tertentu. Misalnya, program dapat menentukan apakah seseorang lulus berdasarkan nilai, menentukan kategori usia berdasarkan umur, atau memberikan diskon berdasarkan jumlah pembelian. Dengan adanya percabangan, program dapat memberikan keluaran yang berbeda sesuai dengan keadaan yang terjadi.
#
# Dalam praktikum ini, struktur percabangan diterapkan melalui beberapa contoh program sederhana. Selain mempelajari bentuk dasar percabangan, praktikum juga membahas penggunaan multi-if untuk mengevaluasi beberapa kondisi secara terpisah. Penerapan konsep tersebut kemudian digunakan dalam sebuah studi kasus berupa sistem loket wahana yang melakukan pemilihan paket, validasi pengunjung, perhitungan diskon, dan evaluasi transaksi.
#
# Oleh karena itu, pemahaman mengenai struktur percabangan sangat diperlukan agar dapat membuat program yang mampu mengambil keputusan berdasarkan kondisi secara tepat dan terstruktur.
#
# ## 1.2 Tujuan
#
# 1. Memahami konsep dasar struktur percabangan dalam bahasa pemrograman Python.
# 2. Mengetahui fungsi dan penggunaan `if`, `if-else`, dan `if-elif-else` dalam program.
# 3. Mampu membuat program yang dapat mengambil keputusan berdasarkan kondisi tertentu.
# 4. Mampu menerapkan operator perbandingan dan operator logika seperti 'and', 'or', dan '!=' dalam struktur percabangan.
# 5. Memahami penggunaan match-case sebagai salah satu bentuk pemilihan kondisi berdasarkan nilai.
# 5. Meningkatkan kemampuan dalam menyusun algoritma yang terstruktur dan sesuai dengan kondisi yang diberikan.
#
#
# ## 1.3 Manfaat
#
# 1. Meningkatkan kemampuan dalam menggunakan struktur 'if', 'if-else', 'if-elif-else', 'multi-if', dan 'match-case'.
# 2. Melatih kemampuan berpikir logis dan sistematis dalam menyelesaikan suatu permasalahan.
# 3. Membuat program menjadi lebih fleksibel, interaktif, dan sesuai dengan kebutuhan.
# 4. Meningkatkan kemampuan dalam menyusun algoritma yang terstruktur dan logis.
# 5. Meningkatkan kemampuan membaca, menjalankan, dan menganalisis kode program Python.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
#
# ### 1. Struktur Percabangan
#
# Struktur percabangan merupakan salah satu konsep dasar dalam pemrograman yang digunakan untuk membuat program mengambil keputusan berdasarkan kondisi tertentu. Dengan percabangan, program dapat menjalankan perintah yang berbeda sesuai dengan keadaan atau nilai yang diberikan oleh pengguna. Dalam Python, struktur percabangan yang umum digunakan antara lain if, if-else, if-elif-else, multi-if, dan match-case.
#
# ### 2. Struktur if
#
# if digunakan untuk menjalankan suatu perintah apabila kondisi yang diberikan bernilai benar. Jika kondisi bernilai salah, perintah di dalam if tidak akan dijalankan.
#
# Contoh penggunaan if adalah:
#
# nilai = 80
#
# if nilai >= 75:
#
#     print("Lulus")
#
# ### 3. Struktur if-else
#
# if-else digunakan ketika terdapat dua kemungkinan hasil. Jika kondisi pada if benar, program menjalankan perintah pada bagian if. Jika salah, program menjalankan perintah pada bagian else.
#
# Contoh penggunaan if-else adalah:
#
# nilai = 60
#
# if nilai >= 75:
#
#     print("Lulus")
#
# else:
#
#     print("Tidak Lulus")
#
# ### 4. Struktur if-elif-else
#
# if-elif-else digunakan untuk memeriksa beberapa kondisi secara berurutan. Program akan menjalankan blok perintah pada kondisi yang pertama kali bernilai benar.
#
# Contoh penggunaan if-elif-else adalah:
#
# nilai = 85
#
# if nilai >= 90:
#
#     print("Sangat Baik")
#
# elif nilai >= 75:
#
#    print("Baik")
# else:
#
#  print("Perlu Belajar Lagi")
#
# ### 5. Multi-if
#
# Multi-if adalah penggunaan beberapa pernyataan if secara terpisah dalam satu program. Berbeda dengan if-elif-else, setiap kondisi pada multi-if diperiksa secara independen. Artinya, lebih dari satu kondisi dapat bernilai benar dan semua perintah dari kondisi yang terpenuhi dapat dijalankan.
#
# ### 6. Operator Perbandingan dan Logika
#
# Operator perbandingan dan operator logika digunakan dalam struktur percabangan untuk menentukan dan menggabungkan kondisi tertentu. Operator perbandingan digunakan untuk membandingkan dua nilai dan menghasilkan nilai True atau False. Operator yang umum digunakan yaitu == (sama dengan), != (tidak sama dengan), > (lebih besar), < (lebih kecil), >= (lebih besar atau sama dengan), dan <= (lebih kecil atau sama dengan). Sementara itu, operator logika digunakan untuk menggabungkan atau memodifikasi beberapa kondisi. Operator logika dalam Python terdiri dari and, or, dan not. Penggunaan kedua jenis operator tersebut memungkinkan program membuat keputusan berdasarkan kondisi yang lebih kompleks.
#
# ### 7. Input dan Konversi Data
#
# Fungsi input() digunakan untuk menerima data yang dimasukkan oleh pengguna melalui keyboard. Secara default, hasil dari input() berupa data bertipe string.
#
# Untuk mendapatkan tipe data tertentu, input dapat dikonversi menggunakan fungsi seperti int() dan float(). Fungsi int() digunakan untuk mengubah data menjadi bilangan bulat, sedangkan float() digunakan untuk mengubah data menjadi bilangan desimal.
#
# Contohnya:
#
# umur_2034 = int(input("Input umur anda: "))
#
# ### 8. Penggunaan strip(), lower(), dan [0]
#
# Metode. strip() digunakan untuk menghapus spasi yang terdapat di awal atau akhir teks. Metode. lower() digunakan untuk mengubah seluruh huruf dalam teks menjadi huruf kecil. Kedua metode tersebut dapat digunakan untuk membuat input pengguna lebih mudah dibandingkan dengan kondisi yang telah ditentukan.
#
# Contohnya:
#
# input_member_2034 = input("Apakah Anda member? (y/t): ").strip().lower()
#
# [0] dapat digunakan untuk mengambil karakter pertama dari sebuah string. Pada program pemeriksaan SIM C, [0] digunakan untuk mengambil karakter pertama dari jawaban pengguna, misalnya y atau t.
#
# ### 9. match-case
#
# match-case merupakan struktur percabangan pada Python yang digunakan untuk mencocokkan suatu nilai dengan beberapa pola atau pilihan yang telah ditentukan. Struktur ini dapat digunakan sebagai alternatif dari if-elif-else ketika program memiliki banyak pilihan berdasarkan nilai tertentu. match digunakan untuk menentukan nilai yang akan diperiksa, sedangkan case digunakan untuk menentukan pola atau nilai yang akan dicocokkan.
#
# Contoh Penggunaan:
#
# bulan_2034 = int(input("Masukkan angka bulan (1 - 12): "))
#
# match bulan_2034:
#
#     case 1:
#
#         print("Januari")
#
#     case 2:
#
#             print("Februari")
#
#     case 3:
#
#             print("Maret")
#
# ### 10. Operasi Perhitungan Diskon
#
# Dalam program perhitungan diskon, operator aritmatika digunakan untuk menghitung nominal diskon dan total pembayaran. Persentase diskon diubah terlebih dahulu menjadi bentuk desimal dengan membaginya dengan 100.
#
# Rumus yang digunakan adalah:
#
# Nominal Diskon = Total Belanja × (Total Diskon / 100)
#
# Total Bayar = Total Belanja - Nominal Diskon
#
# Pada program multi-if, beberapa persentase diskon dapat dijumlahkan terlebih dahulu apabila pengguna memenuhi beberapa syarat diskon.
#
# ### 11. Konversi Nilai Angka Menjadi Nilai Huruf
#
# Struktur if-elif-else dapat digunakan untuk mengelompokkan nilai angka ke dalam kategori tertentu. Pada program yang dibuat, nilai angka dikonversi menjadi nilai huruf berdasarkan rentang nilai.
#
# Contoh:
#
# nilai_2034 = int(input("Inputkan nilai angka= "))
#
# if nilai_2034 >= 81:
#
#     print("A")
#
# elif nilai_2034 >= 70:
#
#     print("B")
#
# elif nilai_2034 >= 60:
#
#     print("C")
#
# elif nilai_2034 >= 50:
#
#     print("D")
#
# else:
#
#     print("E")

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "if1_2611532034.py"

# %%
# Buat file dengan nama if1_nim.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()

ipk_2034 = float(input("Input IPK Anda = "))

if ipk_2034 > 2.75:
    print ("Anda Lulus Sangat Memuaskan dengan IPK " + str(ipk_2034))

print("Program Selesai")
# Out:
# Anda Lulus Sangat Memuaskan dengan IPK 3.5
# Program Selesai

# %% [markdown]
# **Penjelasan:**
#
# 1. `input()` digunakan untuk memasukkan nilai IPK, lalu `float()` mengubahnya menjadi angka desimal.
# 2. `if ipk_2034 >= 2.75` mengecek apakah IPK memenuhi batas kelulusan.
# 3. Jika IPK ≥ 2.75, program menampilkan pesan “Lulus Sangat Memuaskan”.
# 4. Jika IPK < 2.75, pesan kelulusan tidak ditampilkan.
# 5. `print("Program selesai")` tetap dijalankan setelah percabangan selesai.

# %% [markdown]
# ### 2.2.2 Program "if2_2611532034.py"

# %%
# Buat file dengan nama if2_nim.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()

ipk_2034 = float(input("Input IPK Anda = "))

if ipk_2034 > 2.75:
    print("Anda Lulus Sangat Memuaskan dengan IPK " + str(ipk_2034))
else:
    print("Anda Tidak Lulus")
print("Program Selesai")
# Out:
# Anda Lulus Sangat Memuaskan dengan IPK 3.5
# Program Selesai

# %% [markdown]
# **Penjelasan:**
#
# 1. `input()` digunakan untuk memasukkan nilai IPK, kemudian `float()` mengubahnya menjadi angka desimal.
# 2. `if ipk_2034 > 2.75` digunakan untuk mengecek apakah IPK lebih dari 2.75.
# 3. Jika kondisi benar, program menampilkan “Anda Lulus Sangat Memuaskan” beserta nilai IPK.
# 4. Jika kondisi salah, bagian `else` dijalankan dan menampilkan “Anda Tidak Lulus”.
# 5. `print("Program Selesai")` menampilkan pesan bahwa program telah selesai.

# %% [markdown]
# ### 2.2.3 Program "multi_if1_2611532034.py"

# %%
# Buat file dengan nama multi_if1_nim.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()

umur_2034 = int(input("Input umur anda: "))
sim_2034 = input("Apakah Anda Sudah Punya Sim C (y/t): ")[0]

if umur_2034 >= 17 and sim_2034 == 'y':
    print("Anda sudah dewasa dan boleh bawa motor")

if umur_2034 >= 17 and sim_2034 != 'y':
    print ("Anda sudah dewasa tetapi tidak boleh bawa motor")

if umur_2034 < 17 and sim_2034 == 'y':
    print("Anda belum cukup umur punya SIM")

if umur_2034 < 17 and sim_2034 != 'y':
    print("Anda belum cukup umur bawa motor")
# Out:
# Anda sudah dewasa dan boleh bawa motor

# %% [markdown]
# **Penjelasan:**
#
# 1. umur_2034 menerima input 19 dan diubah menjadi bilangan bulat dengan int().
# 2. sim_2034 menerima input y, yang berarti sudah memiliki SIM C.
# 3. Kondisi pertama umur_2034 >= 17 and sim_2034 == 'y' bernilai True karena umur 19 ≥ 17 dan memiliki SIM C.
# 4. Program menampilkan “Anda sudah dewasa dan boleh bawa motor”.
# 5. Tiga kondisi lainnya bernilai False, sehingga tidak menghasilkan output.

# %% [markdown]
# ### 2.2.4 Program "multi_if2_2611532034.py"

# %%
# Buat file dengan nama multi_if2_nim.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir contoh: total_belanja_1234
# Program ini menggunakan fungsi input()
# Program Menghitung Diskon Belanja

# Input dari user
total_belanja_2034 = float(input("Masukkan total belanja (Rp): "))

# Input status member (mengecek apakah user mengetik 'y' atau 'ya')
input_member_2034 = input("Apakah anda member? (y/t): ").strip().lower()
is_member_2034 = input_member_2034 in ["y","ya"]

# Input status kode promo (mengecek apakah user mengetik 'y' atau 'ya')
input_promo_2034 = input("Apakah kode promo valid? (y/t): ").strip().lower()
kode_promo_valid_2034 = input_promo_2034 in ["y","ya"]

total_diskon_persen_2034 = 0

# Multi-IF terpisah: Setiap kondisi diperiksa secara independen
# Diskon bisa ditumpuk (akumulasi) jika memenuhi beberapa syarat sekaligus

if total_belanja_2034 > 1000000:
    total_diskon_persen_2034 += 10 # Diskon belanja besar

if is_member_2034:
    total_diskon_persen_2034 += 5 # Diskon member

if kode_promo_valid_2034:
    total_diskon_persen_2034 += 15 # Diskon voucher

# Menghitung nominal diskon dan total bayar
nominal_diskon_2034 = total_belanja_2034 * (total_diskon_persen_2034 / 100)
total_bayar_2034 = total_belanja_2034 - nominal_diskon_2034

# Output hasil
print("\n--- Rincian Pembayaran ---")
print(f"Total Diskon : {total_diskon_persen_2034}% (Rp {nominal_diskon_2034:,.0f})")
print(f"Total Bayar : Rp {total_bayar_2034:,.0f}")

print(f"Total diskon yang anda dapatkan: {total_diskon_persen_2034}%")
# Output: Total diskon yang anda dapatkan: 30% jika belanja > 1 juta, member, dan kode promosi valid
# Out:
# --- Rincian Pembayaran ---
# Total Diskon : 30% (Rp 600,000)
# Total Bayar : Rp 1,400,000
# Total diskon yang anda dapatkan: 30%

# %% [markdown]
# **Penjelasan:**
#
# 1. Baris 1: Menjelaskan nama file Python yang digunakan, yaitu `multi_if2_nim.py`.
# 2. Baris 2: Menjelaskan bahwa program menggunakan percabangan `if`.
# 3. Baris 3: Menjelaskan bahwa nama variabel menggunakan tambahan 4 digit NIM.
# 4. Baris 4: Menjelaskan bahwa program menggunakan fungsi `input()` untuk menerima data dari pengguna.
# 5. Baris 5: Menjelaskan bahwa program digunakan untuk menghitung diskon belanja.
# 6. Baris 7: Menandai bagian input data dari pengguna.
# 7. Baris 8: Meminta pengguna memasukkan total belanja dan mengubah input menjadi tipe data `float`.
# 8. Baris 10: Menjelaskan bagian input untuk status member.
# 9. Baris 11: Meminta status member, kemudian menghapus spasi dengan `strip()` dan mengubah huruf menjadi kecil dengan `lower()`.
# 10. Baris 12: Menentukan apakah pengguna merupakan member berdasarkan input `y` atau `ya`.
# 11. Baris 14: Menjelaskan bagian input untuk status kode promo.
# 12. Baris 15: Meminta pengguna memasukkan status kode promo, kemudian membersihkan dan mengubah input menjadi huruf kecil.
# 13. Baris 16: Menentukan apakah kode promo dianggap valid berdasarkan input yang diberikan.
# 14. Baris 18: Mengatur nilai awal total diskon menjadi `0%`.
# 15. Baris 20: Menjelaskan bahwa setiap kondisi `if` akan diperiksa secara terpisah.
# 16. Baris 21: Menjelaskan bahwa diskon dapat ditambahkan apabila beberapa kondisi terpenuhi.
# 17. Baris 23: Mengecek apakah total belanja lebih dari Rp1.000.000.
# 18. Baris 24: Jika syarat terpenuhi, diskon belanja besar ditambahkan sebesar `10%`.
# 19. Baris 26: Mengecek apakah pengguna merupakan member.
# 20. Baris 27: Jika pengguna member, diskon tambahan sebesar `5%` diberikan.
# 21. Baris 29: Mengecek apakah kode promo dinyatakan valid.
# 22. Baris 30: Jika kode promo valid, diskon voucher sebesar `15%` ditambahkan.
# 23. Baris 32: Menjelaskan bagian perhitungan nominal diskon dan total pembayaran.
# 24. Baris 33: Menghitung nominal uang yang mendapatkan potongan berdasarkan total belanja dan persentase diskon.
# 25. Baris 34: Menghitung total pembayaran setelah dikurangi nominal diskon.
# 26. Baris 36: Menandai bagian output hasil program.
# 27. Baris 37: Menampilkan judul atau pemisah untuk rincian pembayaran.
# 28. Baris 38: Menampilkan persentase total diskon dan nominal uang yang didapat dari diskon.
# 29. Baris 39: Menampilkan jumlah total yang harus dibayar setelah diskon.
# 30. Baris 41: Menampilkan kembali total persentase diskon yang diperoleh pengguna.
# 31. Baris 42: Menjelaskan contoh hasil output, yaitu diskon `30%` apabila ketiga syarat terpenuhi.

# %% [markdown]
# ### 2.2.5 Program "if_elif_else1_2611532034.py"

# %%
# Buat file dengan nama if_elif_else_nim.py
# Buat program untuk kondisional if
# Nama variabel ditambah 4 digit nim terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()

umur_2034 = int(input("Input umur anda: "))
sim_2034 = input("Apakah Anda Sudah Punya Sim C: ")[0]

if umur_2034 >= 17 and sim_2034 == 'y':
    print("Anda sudah dewasa dan boleh bawa motor")
elif umur_2034 >= 17 and sim_2034 != 'y':
    print("Anda sudah dewasa tetapi tidak boleh bawa motor")
elif umur_2034 <17 and sim_2034 == 'y':
    print("Anda belum cukup umur punya SIM")
else:
    print("Anda belum cukup umur dan tidak boleh bawa motor")
print("Program Selesai")
# Out:
# Anda sudah dewasa dan boleh bawa motor
# Program Selesai

# %% [markdown]
# **Penjelasan:**
#
# 1. Baris 1: Menjelaskan nama file Python yang digunakan, yaitu `if_elif_else_nim.py`.
# 2. Baris 2: Menjelaskan bahwa program menggunakan struktur kondisional `if`.
# 3. Baris 3: Menjelaskan bahwa nama variabel menggunakan tambahan 4 digit NIM.
# 4. Baris 4: Menjelaskan bahwa program menggunakan fungsi `input()` untuk menerima data dari pengguna.
# 5. Baris 6: Meminta pengguna memasukkan umur dan mengubah input menjadi tipe data `integer`.
# 6. Baris 7: Meminta pengguna memasukkan status kepemilikan SIM C dan mengambil karakter pertama dari input.
# 7. Baris 9: Mengecek apakah umur pengguna minimal 17 tahun dan memiliki SIM C.
# 8. Baris 10: Menampilkan pesan bahwa pengguna sudah dewasa dan boleh membawa motor jika kondisi terpenuhi.
# 9. Baris 11: Mengecek kondisi kedua, yaitu pengguna berusia minimal 17 tahun tetapi tidak memiliki SIM C.
# 10. Baris 12: Menampilkan pesan bahwa pengguna sudah dewasa tetapi tidak boleh membawa motor.
# 11. Baris 13: Mengecek kondisi ketiga, yaitu pengguna berusia di bawah 17 tahun tetapi memiliki SIM C.
# 12. Baris 14: Menampilkan pesan bahwa pengguna belum cukup umur untuk memiliki SIM.
# 13. Baris 15: Menjadi kondisi terakhir apabila semua kondisi sebelumnya tidak terpenuhi.
# 14. Baris 16: Menampilkan pesan bahwa pengguna belum cukup umur dan tidak boleh membawa motor.
# 15. Baris 17: Menampilkan tulisan `"Program Selesai"` sebagai tanda bahwa program telah selesai dijalankan.

# %% [markdown]
# ### 2.2.6 Program "nilai_2611532034.py"

# %%
# Buat file dengan nama nilai_nim.py
# Buat program untuk nested if
# Nama variabel ditambah 4 digit nim terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()
# Program konversi nilai angka menjadi huruf

nilai_2034 = int(input("Inputkan nilai angka= "))

if nilai_2034 >= 81:
    print("A")
elif nilai_2034 >= 70:
    print("B")
elif nilai_2034 >= 60:
    print("C")
elif nilai_2034 >= 50:
    print("D")
else:
    print("E")
# Out:
# A

# %% [markdown]
# **Penjelasan:**
#
# 1. Baris 1: Menjelaskan nama file Python yang digunakan, yaitu `nilai_nim.py`.
# 2. Baris 2: Menjelaskan bahwa program menggunakan struktur `nested if`.
# 3. Baris 3: Menjelaskan bahwa nama variabel menggunakan tambahan 4 digit NIM.
# 4. Baris 4: Menjelaskan bahwa program menggunakan fungsi `input()` untuk menerima data dari pengguna.
# 5. Baris 5: Menjelaskan bahwa program digunakan untuk mengubah nilai angka menjadi nilai huruf.
# 6. Baris 7: Meminta pengguna memasukkan nilai angka dan mengubah input menjadi tipe data `integer`.
# 7. Baris 9: Mengecek apakah nilai yang dimasukkan lebih besar atau sama dengan 81.
# 8. Baris 10: Jika kondisi terpenuhi, program menampilkan nilai huruf A.
# 9. Baris 11: Mengecek apakah nilai lebih besar atau sama dengan 70 jika kondisi sebelumnya tidak terpenuhi.
# 10. Baris 12: Jika kondisi terpenuhi, program menampilkan nilai huruf B.
# 11. Baris 13: Mengecek apakah nilai lebih besar atau sama dengan 60.
# 12. Baris 14: Jika kondisi terpenuhi, program menampilkan nilai huruf C.
# 13. Baris 15: Mengecek apakah nilai lebih besar atau sama dengan 50.
# 14. Baris 16: Jika kondisi terpenuhi, program menampilkan nilai huruf D.
# 15. Baris 17: Menjadi kondisi terakhir jika semua kondisi sebelumnya tidak terpenuhi.
# 16. Baris 18: Menampilkan nilai huruf E jika nilai kurang dari 50.

# %% [markdown]
# ### 2.2.7 Program "match_case_2611532034.py"

# %%
# Buat file dengan nama match_case1.py
# Buat program untuk match case
# Nama variabel ditambah 4 digit nim terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()
# Program konversi angka menjadi nama bulan

bulan_2034 = int(input("Masukkan angka bulan (1 - 12): "))

match bulan_2034:
    case 1:
        print("Januari")
    case 2:
            print("Februari")
    case 3:
            print("Maret")
    case 4:
            print("April")
    case 5:
            print("Mei")
    case 6:
            print("Juni")
    case 7:
            print("Juli")
    case 8:
            print("Agustus")
    case 9:
            print("September")
    case 10:
            print("Oktober")
    case 11:
            print("November")
    case 12:
            print("Desember")
    case _:
        print("Angka tidak valid")
# Out:
# Januari

# %% [markdown]
# **Penjelasan:**
#
# 1. Baris 1: Menjelaskan nama file Python yang digunakan, yaitu `match_case1.py`.
# 2. Baris 2: Menjelaskan bahwa program menggunakan struktur `match-case`.
# 3. Baris 3: Menjelaskan bahwa nama variabel menggunakan tambahan 4 digit NIM.
# 4. Baris 4: Menjelaskan bahwa program menggunakan fungsi `input()` untuk menerima data dari pengguna.
# 5. Baris 5: Menjelaskan bahwa program digunakan untuk mengubah angka menjadi nama bulan.
# 6. Baris 7: Meminta pengguna memasukkan angka bulan dan mengubah input menjadi tipe data `integer`.
# 7. Baris 9: Memulai struktur `match-case` untuk mencocokkan nilai yang dimasukkan dengan pilihan kasus yang tersedia.
# 8. Baris 10: Menentukan kondisi untuk angka `1`.
# 9. Baris 11: Menampilkan nama bulan Januari jika angka yang dimasukkan adalah `1`.
# 10. Baris 12: Menentukan kondisi untuk angka `2`.
# 11. Baris 13: Menampilkan nama bulan Februari jika angka yang dimasukkan adalah `2`.
# 12. Baris 14: Menentukan kondisi untuk angka `3`.
# 13. Baris 15: Menampilkan nama bulan Maret jika angka yang dimasukkan adalah `3`.
# 14. Baris 16: Menentukan kondisi untuk angka `4`.
# 15. Baris 17: Menampilkan nama bulan April jika angka yang dimasukkan adalah `4`.
# 16. Baris 18: Menentukan kondisi untuk angka `5`.
# 17. Baris 19: Menampilkan nama bulan Mei jika angka yang dimasukkan adalah `5`.
# 18. Baris 20: Menentukan kondisi untuk angka `6`.
# 19. Baris 21: Menampilkan nama bulan Juni jika angka yang dimasukkan adalah `6`.
# 20. Baris 22: Menentukan kondisi untuk angka `7`.
# 21. Baris 23: Menampilkan nama bulan Juli jika angka yang dimasukkan adalah `7`.
# 22. Baris 24: Menentukan kondisi untuk angka `8`.
# 23. Baris 25: Menampilkan nama bulan Agustus jika angka yang dimasukkan adalah `8`.
# 24. Baris 26: Menentukan kondisi untuk angka `9`.
# 25. Baris 27: Menampilkan nama bulan September jika angka yang dimasukkan adalah `9`.
# 26. Baris 28: Menentukan kondisi untuk angka `10`.
# 27. Baris 29: Menampilkan nama bulan Oktober jika angka yang dimasukkan adalah `10`.
# 28. Baris 30: Menentukan kondisi untuk angka `11`.
# 29. Baris 31: Menampilkan nama bulan November jika angka yang dimasukkan adalah `11`.
# 30. Baris 32: Menentukan kondisi untuk angka `12`.
# 31. Baris 33: Menampilkan nama bulan Desember jika angka yang dimasukkan adalah `12`.
# 32. Baris 34: Menggunakan `case _` sebagai kondisi default jika angka yang dimasukkan tidak sesuai dengan angka 1 sampai 12.
# 33. Baris 35: Menampilkan pesan "Angka tidak valid" jika input bukan angka bulan yang valid.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# Soal :
#
# Sebuah wahana rekreasi petualangan membutuhkan sistem loket berbasis konsol untuk menentukan jenis wahana, memverifikasi kelaikan pengunjung dengan kondisi majemuk (logical operators), menghitung diskon akumulatif menggunakan multi-if terpisah, serta mencetak audit status operasional.

# %% [markdown]
# Kode Jawaban :
#
# a. Kode Program "Tugas4_2611532034.py"

# %%
print("=== SISTEM LOKET ALPRO ADVENTURE PARK ===")

# 1. Input Data Pengunjung

nama_pengunjung_2034 = input("Masukkan Nama Pengunjung            : ")
umur_2034 = int(input("Input Umur Anda                     : "))
sim_2034 = input("Apakah Anda Sudah Punya SIM C (y/t) : ").strip().lower()

# 2. Pemilihan Wahana Menggunakan match-case

print("\nPilihan Paket Wahana (1-5):")
print(" 1. Safari Rimba         (Rp 50,000)")
print(" 2. Arung Jeram          (Rp 75,000)")
print(" 3. Motor ATV Ekstrim    (Rp 120,000)")
print(" 4. Roller Coaster Kilat (Rp 100,000)")
print(" 5. All-Access VIP       (Rp 220,000)")

paket_2034 = int(input("Masukkan nomor paket(1-5)      : "))
match paket_2034:
    case 1:
        nama_wahana_2034 = "Wahana Safari Rimba"
        harga_satuan_2034 = 50000
    case 2:
        nama_wahana_2034 = "Wahana Arung Jeram"
        harga_satuan_2034 = 75000
    case 3:
        nama_wahana_2034 = "Wahana Motor ATV Ekstrim"
        harga_satuan_2034 = 120000
    case 4:
        nama_wahana_2034 = "Wahana Roller Coaster Kilat"
        harga_satuan_2034 = 100000
    case 5:
        nama_wahana_2034 = "Wahana All-Access VIP"
        harga_satuan_2034 = 220000
    case _:
        print("Paket tidak valid")
        raise SystemExit

jumlah_tiket_2034 = int(input("Masukkan jumlah tiket          : "))
if jumlah_tiket_2034 <= 0:
    print("Peringatan: Kuota tiket tidak valid!")

member_2034 = input("Apakah anda member? (y/t)      : ").strip().lower()
is_member_2034 = member_2034 in ["y","ya","yes"]

promo_2034 = input("Apakah kode promo valid? (y/t) : ").strip().lower()
kode_promo_valid_2034 = promo_2034 in ["y","ya","yes"]

# 3. Validasi Izin Kendali Wahana Menggunakan if - elif - else dan Operator Logika (and, !=)

print("\n--- KELAYAKAN PENGENDARA WAHANA ---")

if paket_2034 == 3 and umur_2034 >= 17 and sim_2034 == 'y':
    status_akses_2034 = "Anda sudah dewasa dan boleh mengendarai ATV sendiri."
elif paket_2034 == 3 and umur_2034 >= 17 and sim_2034 != 'y':
    status_akses_2034 = "Anda sudah dewasa tetapi tidak boleh bawa motor ATV (wajib didampingi instruktur)."
elif paket_2034 == 3 and umur_2034 < 17 and sim_2034 == 'y':
    status_akses_2034 = "Identitas tidak valid: Belum cukup umur memiliki SIM"
else:
    status_akses_2034 = "Anda belum cukup umur dan tidak boleh bawa motor ATV"

print(f"Status Akses: {status_akses_2034}")

# 4. Akumulasi Diskon Bertingkat Menggunakan Multi-IF Terpisah

subtotal_2034 = harga_satuan_2034 * jumlah_tiket_2034

total_diskon_persen_2034 = 0

# Diskon belanja besar
if subtotal_2034 >= 200000:
   total_diskon_persen_2034 += 10

# Diskon member
if is_member_2034:
   total_diskon_persen_2034 += 5

# Diskon voucher promo
if kode_promo_valid_2034:
   total_diskon_persen_2034 += 15

# Diskon tambahan rombongan
if jumlah_tiket_2034 >= 5:
   total_diskon_persen_2034 += 5

# 5. Evaluasi Kelulusan Audit Menggunakan if - else

# Perhitungan nominal diskon dan total bayar
nominal_diskon_2034 = subtotal_2034 * (total_diskon_persen_2034 / 100)

total_bayar_2034 = subtotal_2034 - nominal_diskon_2034

# Evaluasi total bayar
if total_bayar_2034 > 300000:
    catatan_layanan_2034 = "Selamat! Anda berhak mendapatkan Souvenir Gratis."
else:
    catatan_layanan_2034 = "Terima kasih telah berkunjung."

# 6. Rincian Pembayaran dengan f-string format desimal (:,.0f).

print("\n--- RINCIAN PEMBAYARAN ---")
print(f"Nama Pengunjung   : {nama_pengunjung_2034}")
print(f"Wahana            : {nama_wahana_2034}")
print(f"Harga Satuan      : Rp{harga_satuan_2034:,.0f}")
print(f"Jumlah Tiket      : {jumlah_tiket_2034}")
print(f"Subtotal Belanja  : Rp{subtotal_2034:,.0f}")
print(f"Total Diskon      : {total_diskon_persen_2034}% " f"(Rp{nominal_diskon_2034:,.0f})")
print(f"Total Bayar       : Rp{total_bayar_2034:,.0f}")
print(f"Catatan Layanan   : {catatan_layanan_2034}")

print("\nProgram Selesai")
# Out:
# === SISTEM LOKET ALPRO ADVENTURE PARK ===
#
# Pilihan Paket Wahana (1-5):
#  1. Safari Rimba         (Rp 50,000)
#  2. Arung Jeram          (Rp 75,000)
#  3. Motor ATV Ekstrim    (Rp 120,000)
#  4. Roller Coaster Kilat (Rp 100,000)
#  5. All-Access VIP       (Rp 220,000)
#
# --- KELAYAKAN PENGENDARA WAHANA ---
# Status Akses: Anda sudah dewasa dan boleh mengendarai ATV sendiri.
#
# --- RINCIAN PEMBAYARAN ---
# Nama Pengunjung   : Nazril
# Wahana            : Wahana Motor ATV Ekstrim
# Harga Satuan      : Rp120,000
# Jumlah Tiket      : 2
# Subtotal Belanja  : Rp240,000
# Total Diskon      : 30% (Rp72,000)
# Total Bayar       : Rp168,000
# Catatan Layanan   : Terima kasih telah berkunjung.
#
# Program Selesai

# %% [markdown]
# Penjelasan :
#
# Baris 1–5 berfungsi untuk menampilkan judul program serta meminta input data pengunjung berupa nama, umur, kepemilikan SIM C, dan jumlah tiket.
#
# Baris 8–9 berfungsi untuk melakukan validasi jumlah tiket menggunakan if tunggal. Jika jumlah tiket kurang dari atau sama dengan 0, program akan menampilkan peringatan bahwa kuota tiket tidak valid.
#
# Baris 13–18 berfungsi untuk menampilkan daftar pilihan paket wahana beserta harga masing-masing paket.
#
# Baris 20 berfungsi untuk menerima input nomor paket wahana yang dipilih oleh pengguna dan mengubah input tersebut menjadi tipe data integer.
#
# Baris 22–45 berfungsi untuk menentukan nama wahana dan harga satuan berdasarkan nomor paket yang dipilih menggunakan struktur match-case. case 1 sampai case 5 digunakan untuk menentukan lima pilihan wahana yang tersedia, sedangkan case _ digunakan untuk menangani input paket yang tidak valid.
#
# Baris 47–48 berfungsi untuk menghentikan program apabila pengguna memasukkan nomor paket yang tidak tersedia.
#
# Baris 53–82 berfungsi untuk melakukan pemeriksaan kelayakan pengunjung dalam menggunakan wahana. Pada paket Motor ATV Ekstrim, kondisi diperiksa berdasarkan umur dan kepemilikan SIM C menggunakan operator logika and dan !=. Untuk paket selain ATV, kelayakan diperiksa berdasarkan umur minimal 10 tahun.
#
# Baris 84 berfungsi untuk menampilkan hasil pemeriksaan kelayakan pengunjung berdasarkan kondisi yang telah dievaluasi sebelumnya.
#
# Baris 88–92 berfungsi untuk meminta input status keanggotaan pengguna dan validitas kode promo. Input kemudian diubah menjadi huruf kecil menggunakan .lower() agar dapat dibandingkan dengan kondisi yang telah ditentukan.
#
# Baris 97 berfungsi untuk menghitung subtotal belanja dengan mengalikan harga satuan wahana dengan jumlah tiket yang dibeli.
#
# Baris 102–117 berfungsi untuk menghitung total diskon menggunakan beberapa if yang berdiri secara terpisah. Diskon diberikan berdasarkan subtotal belanja, status member, kode promo, dan jumlah tiket. Karena menggunakan multi-if, beberapa diskon dapat diperoleh dan dijumlahkan secara bersamaan.
#
# Baris 122–127 berfungsi untuk menghitung nominal diskon dan total pembayaran. Nominal diskon diperoleh dari subtotal dikalikan persentase diskon, kemudian total pembayaran diperoleh dengan mengurangi subtotal dengan nominal diskon.
#
# Baris 132–139 berfungsi untuk melakukan evaluasi akhir menggunakan if-else. Jika total pembayaran lebih dari Rp300.000, pengguna mendapatkan informasi bahwa dirinya berhak memperoleh souvenir gratis. Jika tidak, program menampilkan ucapan terima kasih.
#
# Baris 144–159 berfungsi untuk menampilkan seluruh rincian transaksi, yaitu nama pengunjung, nama wahana, harga satuan, jumlah tiket, subtotal, total diskon, total pembayaran, dan catatan layanan. Format :,.0f digunakan untuk menampilkan nominal angka dengan pemisah ribuan tanpa angka desimal.
#
# Baris 161 berfungsi untuk menampilkan pesan bahwa program telah selesai dijalankan.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa struktur percabangan pada Python digunakan untuk membuat program yang dapat mengambil keputusan berdasarkan kondisi tertentu. Struktur if, if-elif-else, dan match-case memiliki fungsi yang berbeda sesuai dengan kebutuhan program. Struktur if digunakan untuk menjalankan perintah berdasarkan satu kondisi, if-elif-else digunakan untuk memilih salah satu dari beberapa kondisi, sedangkan match-case digunakan untuk mencocokkan suatu nilai dengan beberapa pilihan kasus.
#
# Penggunaan operator logika seperti and, or, dan != juga dapat membantu membentuk kondisi yang lebih kompleks. Selain itu, penerapan struktur percabangan pada studi kasus Sistem Loket Alpro Adventure Park menunjukkan bahwa konsep percabangan dapat digunakan untuk menyelesaikan permasalahan yang lebih nyata, seperti pemilihan wahana, validasi kelayakan pengunjung, pemberian diskon, dan evaluasi hasil transaksi.
#
# Dengan memahami struktur percabangan tersebut, program dapat dibuat lebih terarah, fleksibel, dan mampu memberikan output sesuai dengan kondisi atau input yang diberikan pengguna.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Python Software Foundation, *"More Control Flow Tools,"* *Python Documentation,* [2026]. [Online]. Tersedia: [https://docs.python.org/3/tutorial/controlflow.html](https://docs.python.org/3/tutorial/controlflow.html?utm_source=chatgpt.com) [Diakses 26 September 2026].
#
# [2] Python Software Foundation, *"Lebih Banyak Alat Pengatur Aliran Control Flow,"* *Dokumentasi Python,* [2026]. [Online]. Tersedia: [https://docs.python.org/id/3.14/tutorial/controlflow.html](https://docs.python.org/id/3.14/tutorial/controlflow.html?utm_source=chatgpt.com) [Diakses 26 September 2026].
#
# [3] Python Software Foundation, *"Compound statements,"* *Python Language Reference,* [2026]. [Online]. Tersedia: [https://docs.python.org/3/reference/compound_stmts.html](https://docs.python.org/3/reference/compound_stmts.html?utm_source=chatgpt.com) [Diakses 26 September 2026].
